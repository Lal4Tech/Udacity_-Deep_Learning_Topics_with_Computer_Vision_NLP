# %%
# install dependencies
# !pip install smdebug
# Out:
# Requirement already satisfied: smdebug in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (1.0.12)
# Requirement already satisfied: boto3>=1.10.32 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from smdebug) (1.21.42)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from smdebug) (21.3)
# Requirement already satisfied: protobuf>=3.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from smdebug) (3.15.2)
# Requirement already satisfied: pyinstrument==3.4.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from smdebug) (3.4.2)
# Requirement already satisfied: numpy>=1.16.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from smdebug) (1.19.5)
# Requirement already satisfied: pyinstrument-cext>=0.2.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pyinstrument==3.4.2->smdebug) (0.2.4)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.10.32->smdebug) (0.10.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.10.32->smdebug) (0.5.0)
# Requirement already satisfied: botocore<1.25.0,>=1.24.42 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.10.32->smdebug) (1.24.42)
# Requirement already satisfied: six>=1.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from protobuf>=3.6.0->smdebug) (1.15.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from packaging->smdebug) (2.4.7)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.25.0,>=1.24.42->boto3>=1.10.32->smdebug) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.25.0,>=1.24.42->boto3>=1.10.32->smdebug) (1.26.8)

# %%
from sagemaker.debugger import Rule, ProfilerRule, rule_configs
from sagemaker.debugger import DebuggerHookConfig, ProfilerConfig, FrameworkProfile
import sagemaker
from sagemaker.pytorch import PyTorch
import boto3
from smdebug.trials import create_trial
from smdebug.core.modes import ModeKeys
from smdebug.profiler.analysis.notebook_utils.training_job import TrainingJob
from smdebug.profiler.analysis.notebook_utils.timeline_charts import TimelineCharts
import os
import IPython
# Out:
# [2022-05-07 12:33:14.817 ip-172-16-17-202:32741 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None

# %%
rules = [
    Rule.sagemaker(rule_configs.loss_not_decreasing()),
    ProfilerRule.sagemaker(rule_configs.LowGPUUtilization()),
    ProfilerRule.sagemaker(rule_configs.ProfilerReport()),
    Rule.sagemaker(rule_configs.vanishing_gradient()),
    Rule.sagemaker(rule_configs.overfit()),
    Rule.sagemaker(rule_configs.overtraining()),
    Rule.sagemaker(rule_configs.poor_weight_initialization()),
]

# %%
profiler_config = ProfilerConfig(
    system_monitor_interval_millis=500, framework_profile_params=FrameworkProfile(num_steps=10)
)
debugger_config = DebuggerHookConfig(
    hook_parameters={"train.save_interval": "100", "eval.save_interval": "10"}
)

# %%
hyperparameters = {
    "batch_size": 2048,
    "gpu": True,
    "epoch": 2,
    "model": "resnet50",
}

# %%
role = sagemaker.get_execution_role()
session = sagemaker.Session()
region = session.boto_region_name
bucket = session.default_bucket()
output_path = f's3://{bucket}/jobs'
job_name = "smdebugger-debugger-and-profiler-cifar-pytorch"
estimator = PyTorch(
    base_job_name=job_name,
    role=role,
    source_dir="scripts",
    entry_point="pytorch_cifar_profiling.py",
    hyperparameters=hyperparameters,
    framework_version="1.8",
    py_version="py36",
    instance_type="ml.p2.xlarge",
    instance_count=1,
    use_spot_instances = True,
    checkpoint_s3_uri = f'{output_path}/{job_name}/checkpoints',
    max_run=1200,
    max_wait=1800,
    ## Profile and Debug parameters
    rules=rules,
    profiler_config=profiler_config,
    debugger_hook_config=debugger_config
)

# %%
estimator.fit(wait=True)
# Out:
# 2022-05-07 12:49:57 Starting - Starting the training job...
# 2022-05-07 12:49:59 Starting - Launching requested ML instancesLossNotDecreasing: InProgress
# VanishingGradient: InProgress
# Overfit: InProgress
# Overtraining: InProgress
# PoorWeightInitialization: InProgress
# LowGPUUtilization: InProgress
# ProfilerReport: InProgress
# ......
# 2022-05-07 12:51:24 Starting - Preparing the instances for training...............
# 2022-05-07 12:53:57 Downloading - Downloading input data............
# 2022-05-07 12:55:57 Training - Downloading the training image...............
# 2022-05-07 12:58:18 Training - Training image download completed. Training in progress...................
# 2022-05-07 13:01:19 Interrupted - Training job interrupted...........................
# 2022-05-07 13:06:02 Starting - Starting the training job......
# 2022-05-07 13:07:01 Starting - Launching requested ML instances.........
# 2022-05-07 13:08:21 Starting - Insufficient capacity error from EC2 while launching instances, retrying!..............................
# 2022-05-07 13:13:23 Starting - Preparing the instances for training......LowGPUUtilization: Stopped
# ProfilerReport: Stopped
# ...
# 2022-05-07 13:14:59 Downloading - Downloading input data...
# 2022-05-07 13:15:19 Training - Downloading the training image............LossNotDecreasing: InProgress
# VanishingGradient: InProgress
# Overfit: Stopped
# Overtraining: InProgress
# PoorWeightInitialization: InProgress
# ...LossNotDecreasing: InProgress
# VanishingGradient: InProgress
# Overfit: Stopped
# Overtraining: InProgress
# PoorWeightInitialization: Stopped
# ...LossNotDecreasing: InProgress
# VanishingGradient: InProgress
# Overfit: Stopped
# Overtraining: Stopped
# PoorWeightInitialization: Stopped
# ...LossNotDecreasing: Stopped
# VanishingGradient: InProgress
# Overfit: Stopped
# Overtraining: Stopped
# PoorWeightInitialization: Stopped
# ...LossNotDecreasing: Stopped
# VanishingGradient: Stopped
# Overfit: Stopped
# Overtraining: Stopped
# PoorWeightInitialization: Stopped
# ...bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2022-05-07 13:19:58,973 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2022-05-07 13:19:58,997 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2022-05-07 13:20:00,439 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2022-05-07 13:20:00,981 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch_size": 2048,
#         "epoch": 2,
#         "model": "resnet50",
#         "gpu": true
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "smdebugger-debugger-and-profiler-cifar--2022-05-07-12-49-57-160",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-eu-west-1-663084464644/smdebugger-debugger-and-profiler-cifar--2022-05-07-12-49-57-160/source/sourcedir.tar.gz",
#     "module_name": "pytorch_cifar_profiling",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "pytorch_cifar_profiling.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":2048,"epoch":2,"gpu":true,"model":"resnet50"}
# SM_USER_ENTRY_POINT=pytorch_cifar_profiling.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=pytorch_cifar_profiling
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-eu-west-1-663084464644/smdebugger-debugger-and-profiler-cifar--2022-05-07-12-49-57-160/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch_size":2048,"epoch":2,"gpu":true,"model":"resnet50"},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"smdebugger-debugger-and-profiler-cifar--2022-05-07-12-49-57-160","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-eu-west-1-663084464644/smdebugger-debugger-and-profiler-cifar--2022-05-07-12-49-57-160/source/sourcedir.tar.gz","module_name":"pytorch_cifar_profiling","network_interface_name":"eth0","num_cpus":4,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"pytorch_cifar_profiling.py"}
# SM_USER_ARGS=["--batch_size","2048","--epoch","2","--gpu","True","--model","resnet50"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_BATCH_SIZE=2048
# SM_HP_EPOCH=2
# SM_HP_MODEL=resnet50
# SM_HP_GPU=true
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 pytorch_cifar_profiling.py --batch_size 2048 --epoch 2 --gpu True --model resnet50
# [2022-05-07 13:20:04.285 algo-1:27 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-05-07 13:20:04.417 algo-1:27 INFO profiler_config_parser.py:102] Using config at /opt/ml/input/config/profilerconfig.json.
# batch_size:2048
# epoch:2
# gpu:True
# model:resnet50
# [2022-05-07 13:20:11.247 algo-1:27 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2022-05-07 13:20:11.250 algo-1:27 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2022-05-07 13:20:11.251 algo-1:27 INFO hook.py:255] Saving to /opt/ml/output/tensors
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#
# 2022-05-07 13:20:08 Stopping - Stopping the training jobExtracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# START TRAINING
# [2022-05-07 13:20:31.631 algo-1:27 INFO hook.py:591] name:conv1.weight count_params:9408
# [2022-05-07 13:20:31.631 algo-1:27 INFO hook.py:591] name:bn1.weight count_params:64
# [2022-05-07 13:20:31.632 algo-1:27 INFO hook.py:591] name:bn1.bias count_params:64
# [2022-05-07 13:20:31.632 algo-1:27 INFO hook.py:591] name:layer1.0.conv1.weight count_params:4096
# [2022-05-07 13:20:31.633 algo-1:27 INFO hook.py:591] name:layer1.0.bn1.weight count_params:64
# [2022-05-07 13:20:31.633 algo-1:27 INFO hook.py:591] name:layer1.0.bn1.bias count_params:64
# [2022-05-07 13:20:31.633 algo-1:27 INFO hook.py:591] name:layer1.0.conv2.weight count_params:36864
# [2022-05-07 13:20:31.634 algo-1:27 INFO hook.py:591] name:layer1.0.bn2.weight count_params:64
# [2022-05-07 13:20:31.634 algo-1:27 INFO hook.py:591] name:layer1.0.bn2.bias count_params:64
# [2022-05-07 13:20:31.635 algo-1:27 INFO hook.py:591] name:layer1.0.conv3.weight count_params:16384
# [2022-05-07 13:20:31.635 algo-1:27 INFO hook.py:591] name:layer1.0.bn3.weight count_params:256
# [2022-05-07 13:20:31.635 algo-1:27 INFO hook.py:591] name:layer1.0.bn3.bias count_params:256
# [2022-05-07 13:20:31.636 algo-1:27 INFO hook.py:591] name:layer1.0.downsample.0.weight count_params:16384
# [2022-05-07 13:20:31.636 algo-1:27 INFO hook.py:591] name:layer1.0.downsample.1.weight count_params:256
# [2022-05-07 13:20:31.637 algo-1:27 INFO hook.py:591] name:layer1.0.downsample.1.bias count_params:256
# [2022-05-07 13:20:31.637 algo-1:27 INFO hook.py:591] name:layer1.1.conv1.weight count_params:16384
# [2022-05-07 13:20:31.637 algo-1:27 INFO hook.py:591] name:layer1.1.bn1.weight count_params:64
# [2022-05-07 13:20:31.638 algo-1:27 INFO hook.py:591] name:layer1.1.bn1.bias count_params:64
# [2022-05-07 13:20:31.638 algo-1:27 INFO hook.py:591] name:layer1.1.conv2.weight count_params:36864
# [2022-05-07 13:20:31.639 algo-1:27 INFO hook.py:591] name:layer1.1.bn2.weight count_params:64
# [2022-05-07 13:20:31.639 algo-1:27 INFO hook.py:591] name:layer1.1.bn2.bias count_params:64
# [2022-05-07 13:20:31.639 algo-1:27 INFO hook.py:591] name:layer1.1.conv3.weight count_params:16384
# [2022-05-07 13:20:31.640 algo-1:27 INFO hook.py:591] name:layer1.1.bn3.weight count_params:256
# [2022-05-07 13:20:31.640 algo-1:27 INFO hook.py:591] name:layer1.1.bn3.bias count_params:256
# [2022-05-07 13:20:31.641 algo-1:27 INFO hook.py:591] name:layer1.2.conv1.weight count_params:16384
# [2022-05-07 13:20:31.641 algo-1:27 INFO hook.py:591] name:layer1.2.bn1.weight count_params:64
# [2022-05-07 13:20:31.641 algo-1:27 INFO hook.py:591] name:layer1.2.bn1.bias count_params:64
# [2022-05-07 13:20:31.642 algo-1:27 INFO hook.py:591] name:layer1.2.conv2.weight count_params:36864
# [2022-05-07 13:20:31.642 algo-1:27 INFO hook.py:591] name:layer1.2.bn2.weight count_params:64
# [2022-05-07 13:20:31.642 algo-1:27 INFO hook.py:591] name:layer1.2.bn2.bias count_params:64
# [2022-05-07 13:20:31.643 algo-1:27 INFO hook.py:591] name:layer1.2.conv3.weight count_params:16384
# [2022-05-07 13:20:31.643 algo-1:27 INFO hook.py:591] name:layer1.2.bn3.weight count_params:256
# [2022-05-07 13:20:31.644 algo-1:27 INFO hook.py:591] name:layer1.2.bn3.bias count_params:256
# [2022-05-07 13:20:31.644 algo-1:27 INFO hook.py:591] name:layer2.0.conv1.weight count_params:32768
# [2022-05-07 13:20:31.644 algo-1:27 INFO hook.py:591] name:layer2.0.bn1.weight count_params:128
# [2022-05-07 13:20:31.645 algo-1:27 INFO hook.py:591] name:layer2.0.bn1.bias count_params:128
# [2022-05-07 13:20:31.645 algo-1:27 INFO hook.py:591] name:layer2.0.conv2.weight count_params:147456
# [2022-05-07 13:20:31.646 algo-1:27 INFO hook.py:591] name:layer2.0.bn2.weight count_params:128
# [2022-05-07 13:20:31.646 algo-1:27 INFO hook.py:591] name:layer2.0.bn2.bias count_params:128
# [2022-05-07 13:20:31.646 algo-1:27 INFO hook.py:591] name:layer2.0.conv3.weight count_params:65536
# [2022-05-07 13:20:31.647 algo-1:27 INFO hook.py:591] name:layer2.0.bn3.weight count_params:512
# [2022-05-07 13:20:31.647 algo-1:27 INFO hook.py:591] name:layer2.0.bn3.bias count_params:512
# [2022-05-07 13:20:31.648 algo-1:27 INFO hook.py:591] name:layer2.0.downsample.0.weight count_params:131072
# [2022-05-07 13:20:31.648 algo-1:27 INFO hook.py:591] name:layer2.0.downsample.1.weight count_params:512
# [2022-05-07 13:20:31.648 algo-1:27 INFO hook.py:591] name:layer2.0.downsample.1.bias count_params:512
# [2022-05-07 13:20:31.649 algo-1:27 INFO hook.py:591] name:layer2.1.conv1.weight count_params:65536
# [2022-05-07 13:20:31.649 algo-1:27 INFO hook.py:591] name:layer2.1.bn1.weight count_params:128
# [2022-05-07 13:20:31.650 algo-1:27 INFO hook.py:591] name:layer2.1.bn1.bias count_params:128
# [2022-05-07 13:20:31.650 algo-1:27 INFO hook.py:591] name:layer2.1.conv2.weight count_params:147456
# [2022-05-07 13:20:31.650 algo-1:27 INFO hook.py:591] name:layer2.1.bn2.weight count_params:128
# [2022-05-07 13:20:31.651 algo-1:27 INFO hook.py:591] name:layer2.1.bn2.bias count_params:128
# [2022-05-07 13:20:31.651 algo-1:27 INFO hook.py:591] name:layer2.1.conv3.weight count_params:65536
# [2022-05-07 13:20:31.652 algo-1:27 INFO hook.py:591] name:layer2.1.bn3.weight count_params:512
# [2022-05-07 13:20:31.652 algo-1:27 INFO hook.py:591] name:layer2.1.bn3.bias count_params:512
# [2022-05-07 13:20:31.652 algo-1:27 INFO hook.py:591] name:layer2.2.conv1.weight count_params:65536
# [2022-05-07 13:20:31.653 algo-1:27 INFO hook.py:591] name:layer2.2.bn1.weight count_params:128
# [2022-05-07 13:20:31.653 algo-1:27 INFO hook.py:591] name:layer2.2.bn1.bias count_params:128
# [2022-05-07 13:20:31.654 algo-1:27 INFO hook.py:591] name:layer2.2.conv2.weight count_params:147456
# [2022-05-07 13:20:31.654 algo-1:27 INFO hook.py:591] name:layer2.2.bn2.weight count_params:128
# [2022-05-07 13:20:31.654 algo-1:27 INFO hook.py:591] name:layer2.2.bn2.bias count_params:128
# [2022-05-07 13:20:31.655 algo-1:27 INFO hook.py:591] name:layer2.2.conv3.weight count_params:65536
# [2022-05-07 13:20:31.655 algo-1:27 INFO hook.py:591] name:layer2.2.bn3.weight count_params:512
# [2022-05-07 13:20:31.656 algo-1:27 INFO hook.py:591] name:layer2.2.bn3.bias count_params:512
# [2022-05-07 13:20:31.656 algo-1:27 INFO hook.py:591] name:layer2.3.conv1.weight count_params:65536
# [2022-05-07 13:20:31.656 algo-1:27 INFO hook.py:591] name:layer2.3.bn1.weight count_params:128
# [2022-05-07 13:20:31.657 algo-1:27 INFO hook.py:591] name:layer2.3.bn1.bias count_params:128
# [2022-05-07 13:20:31.657 algo-1:27 INFO hook.py:591] name:layer2.3.conv2.weight count_params:147456
# [2022-05-07 13:20:31.658 algo-1:27 INFO hook.py:591] name:layer2.3.bn2.weight count_params:128
# [2022-05-07 13:20:31.658 algo-1:27 INFO hook.py:591] name:layer2.3.bn2.bias count_params:128
# [2022-05-07 13:20:31.658 algo-1:27 INFO hook.py:591] name:layer2.3.conv3.weight count_params:65536
# [2022-05-07 13:20:31.659 algo-1:27 INFO hook.py:591] name:layer2.3.bn3.weight count_params:512
# [2022-05-07 13:20:31.659 algo-1:27 INFO hook.py:591] name:layer2.3.bn3.bias count_params:512
# [2022-05-07 13:20:31.660 algo-1:27 INFO hook.py:591] name:layer3.0.conv1.weight count_params:131072
# [2022-05-07 13:20:31.660 algo-1:27 INFO hook.py:591] name:layer3.0.bn1.weight count_params:256
# [2022-05-07 13:20:31.660 algo-1:27 INFO hook.py:591] name:layer3.0.bn1.bias count_params:256
# [2022-05-07 13:20:31.661 algo-1:27 INFO hook.py:591] name:layer3.0.conv2.weight count_params:589824
# [2022-05-07 13:20:31.661 algo-1:27 INFO hook.py:591] name:layer3.0.bn2.weight count_params:256
# [2022-05-07 13:20:31.661 algo-1:27 INFO hook.py:591] name:layer3.0.bn2.bias count_params:256
# [2022-05-07 13:20:31.662 algo-1:27 INFO hook.py:591] name:layer3.0.conv3.weight count_params:262144
# [2022-05-07 13:20:31.662 algo-1:27 INFO hook.py:591] name:layer3.0.bn3.weight count_params:1024
# [2022-05-07 13:20:31.663 algo-1:27 INFO hook.py:591] name:layer3.0.bn3.bias count_params:1024
# [2022-05-07 13:20:31.663 algo-1:27 INFO hook.py:591] name:layer3.0.downsample.0.weight count_params:524288
# [2022-05-07 13:20:31.664 algo-1:27 INFO hook.py:591] name:layer3.0.downsample.1.weight count_params:1024
# [2022-05-07 13:20:31.664 algo-1:27 INFO hook.py:591] name:layer3.0.downsample.1.bias count_params:1024
# [2022-05-07 13:20:31.664 algo-1:27 INFO hook.py:591] name:layer3.1.conv1.weight count_params:262144
# [2022-05-07 13:20:31.665 algo-1:27 INFO hook.py:591] name:layer3.1.bn1.weight count_params:256
# [2022-05-07 13:20:31.665 algo-1:27 INFO hook.py:591] name:layer3.1.bn1.bias count_params:256
# [2022-05-07 13:20:31.665 algo-1:27 INFO hook.py:591] name:layer3.1.conv2.weight count_params:589824
# [2022-05-07 13:20:31.666 algo-1:27 INFO hook.py:591] name:layer3.1.bn2.weight count_params:256
# [2022-05-07 13:20:31.666 algo-1:27 INFO hook.py:591] name:layer3.1.bn2.bias count_params:256
# [2022-05-07 13:20:31.667 algo-1:27 INFO hook.py:591] name:layer3.1.conv3.weight count_params:262144
# [2022-05-07 13:20:31.667 algo-1:27 INFO hook.py:591] name:layer3.1.bn3.weight count_params:1024
# [2022-05-07 13:20:31.667 algo-1:27 INFO hook.py:591] name:layer3.1.bn3.bias count_params:1024
# [2022-05-07 13:20:31.668 algo-1:27 INFO hook.py:591] name:layer3.2.conv1.weight count_params:262144
# [2022-05-07 13:20:31.668 algo-1:27 INFO hook.py:591] name:layer3.2.bn1.weight count_params:256
# [2022-05-07 13:20:31.669 algo-1:27 INFO hook.py:591] name:layer3.2.bn1.bias count_params:256
# [2022-05-07 13:20:31.669 algo-1:27 INFO hook.py:591] name:layer3.2.conv2.weight count_params:589824
# [2022-05-07 13:20:31.669 algo-1:27 INFO hook.py:591] name:layer3.2.bn2.weight count_params:256
# [2022-05-07 13:20:31.670 algo-1:27 INFO hook.py:591] name:layer3.2.bn2.bias count_params:256
# [2022-05-07 13:20:31.670 algo-1:27 INFO hook.py:591] name:layer3.2.conv3.weight count_params:262144
# [2022-05-07 13:20:31.671 algo-1:27 INFO hook.py:591] name:layer3.2.bn3.weight count_params:1024
# [2022-05-07 13:20:31.671 algo-1:27 INFO hook.py:591] name:layer3.2.bn3.bias count_params:1024
# [2022-05-07 13:20:31.671 algo-1:27 INFO hook.py:591] name:layer3.3.conv1.weight count_params:262144
# [2022-05-07 13:20:31.672 algo-1:27 INFO hook.py:591] name:layer3.3.bn1.weight count_params:256
# [2022-05-07 13:20:31.672 algo-1:27 INFO hook.py:591] name:layer3.3.bn1.bias count_params:256
# [2022-05-07 13:20:31.673 algo-1:27 INFO hook.py:591] name:layer3.3.conv2.weight count_params:589824
# [2022-05-07 13:20:31.673 algo-1:27 INFO hook.py:591] name:layer3.3.bn2.weight count_params:256
# [2022-05-07 13:20:31.673 algo-1:27 INFO hook.py:591] name:layer3.3.bn2.bias count_params:256
# [2022-05-07 13:20:31.674 algo-1:27 INFO hook.py:591] name:layer3.3.conv3.weight count_params:262144
# [2022-05-07 13:20:31.674 algo-1:27 INFO hook.py:591] name:layer3.3.bn3.weight count_params:1024
# [2022-05-07 13:20:31.675 algo-1:27 INFO hook.py:591] name:layer3.3.bn3.bias count_params:1024
# [2022-05-07 13:20:31.675 algo-1:27 INFO hook.py:591] name:layer3.4.conv1.weight count_params:262144
# [2022-05-07 13:20:31.675 algo-1:27 INFO hook.py:591] name:layer3.4.bn1.weight count_params:256
# [2022-05-07 13:20:31.676 algo-1:27 INFO hook.py:591] name:layer3.4.bn1.bias count_params:256
# [2022-05-07 13:20:31.676 algo-1:27 INFO hook.py:591] name:layer3.4.conv2.weight count_params:589824
# [2022-05-07 13:20:31.676 algo-1:27 INFO hook.py:591] name:layer3.4.bn2.weight count_params:256
# [2022-05-07 13:20:31.677 algo-1:27 INFO hook.py:591] name:layer3.4.bn2.bias count_params:256
# [2022-05-07 13:20:31.677 algo-1:27 INFO hook.py:591] name:layer3.4.conv3.weight count_params:262144
# [2022-05-07 13:20:31.678 algo-1:27 INFO hook.py:591] name:layer3.4.bn3.weight count_params:1024
# [2022-05-07 13:20:31.678 algo-1:27 INFO hook.py:591] name:layer3.4.bn3.bias count_params:1024
# [2022-05-07 13:20:31.678 algo-1:27 INFO hook.py:591] name:layer3.5.conv1.weight count_params:262144
# [2022-05-07 13:20:31.679 algo-1:27 INFO hook.py:591] name:layer3.5.bn1.weight count_params:256
# [2022-05-07 13:20:31.679 algo-1:27 INFO hook.py:591] name:layer3.5.bn1.bias count_params:256
# [2022-05-07 13:20:31.680 algo-1:27 INFO hook.py:591] name:layer3.5.conv2.weight count_params:589824
# [2022-05-07 13:20:31.680 algo-1:27 INFO hook.py:591] name:layer3.5.bn2.weight count_params:256
# [2022-05-07 13:20:31.680 algo-1:27 INFO hook.py:591] name:layer3.5.bn2.bias count_params:256
# [2022-05-07 13:20:31.681 algo-1:27 INFO hook.py:591] name:layer3.5.conv3.weight count_params:262144
# [2022-05-07 13:20:31.681 algo-1:27 INFO hook.py:591] name:layer3.5.bn3.weight count_params:1024
# [2022-05-07 13:20:31.681 algo-1:27 INFO hook.py:591] name:layer3.5.bn3.bias count_params:1024
# [2022-05-07 13:20:31.682 algo-1:27 INFO hook.py:591] name:layer4.0.conv1.weight count_params:524288
# [2022-05-07 13:20:31.682 algo-1:27 INFO hook.py:591] name:layer4.0.bn1.weight count_params:512
# [2022-05-07 13:20:31.683 algo-1:27 INFO hook.py:591] name:layer4.0.bn1.bias count_params:512
# [2022-05-07 13:20:31.683 algo-1:27 INFO hook.py:591] name:layer4.0.conv2.weight count_params:2359296
# [2022-05-07 13:20:31.683 algo-1:27 INFO hook.py:591] name:layer4.0.bn2.weight count_params:512
# [2022-05-07 13:20:31.684 algo-1:27 INFO hook.py:591] name:layer4.0.bn2.bias count_params:512
# [2022-05-07 13:20:31.684 algo-1:27 INFO hook.py:591] name:layer4.0.conv3.weight count_params:1048576
# [2022-05-07 13:20:31.685 algo-1:27 INFO hook.py:591] name:layer4.0.bn3.weight count_params:2048
# [2022-05-07 13:20:31.685 algo-1:27 INFO hook.py:591] name:layer4.0.bn3.bias count_params:2048
# [2022-05-07 13:20:31.685 algo-1:27 INFO hook.py:591] name:layer4.0.downsample.0.weight count_params:2097152
# [2022-05-07 13:20:31.686 algo-1:27 INFO hook.py:591] name:layer4.0.downsample.1.weight count_params:2048
# [2022-05-07 13:20:31.686 algo-1:27 INFO hook.py:591] name:layer4.0.downsample.1.bias count_params:2048
# [2022-05-07 13:20:31.687 algo-1:27 INFO hook.py:591] name:layer4.1.conv1.weight count_params:1048576
# [2022-05-07 13:20:31.687 algo-1:27 INFO hook.py:591] name:layer4.1.bn1.weight count_params:512
# [2022-05-07 13:20:31.687 algo-1:27 INFO hook.py:591] name:layer4.1.bn1.bias count_params:512
# [2022-05-07 13:20:31.688 algo-1:27 INFO hook.py:591] name:layer4.1.conv2.weight count_params:2359296
# [2022-05-07 13:20:31.688 algo-1:27 INFO hook.py:591] name:layer4.1.bn2.weight count_params:512
# [2022-05-07 13:20:31.689 algo-1:27 INFO hook.py:591] name:layer4.1.bn2.bias count_params:512
# [2022-05-07 13:20:31.689 algo-1:27 INFO hook.py:591] name:layer4.1.conv3.weight count_params:1048576
# [2022-05-07 13:20:31.689 algo-1:27 INFO hook.py:591] name:layer4.1.bn3.weight count_params:2048
# [2022-05-07 13:20:31.690 algo-1:27 INFO hook.py:591] name:layer4.1.bn3.bias count_params:2048
# [2022-05-07 13:20:31.690 algo-1:27 INFO hook.py:591] name:layer4.2.conv1.weight count_params:1048576
# [2022-05-07 13:20:31.691 algo-1:27 INFO hook.py:591] name:layer4.2.bn1.weight count_params:512
# [2022-05-07 13:20:31.691 algo-1:27 INFO hook.py:591] name:layer4.2.bn1.bias count_params:512
# [2022-05-07 13:20:31.691 algo-1:27 INFO hook.py:591] name:layer4.2.conv2.weight count_params:2359296
# [2022-05-07 13:20:31.692 algo-1:27 INFO hook.py:591] name:layer4.2.bn2.weight count_params:512
# [2022-05-07 13:20:31.692 algo-1:27 INFO hook.py:591] name:layer4.2.bn2.bias count_params:512
# [2022-05-07 13:20:31.693 algo-1:27 INFO hook.py:591] name:layer4.2.conv3.weight count_params:1048576
# [2022-05-07 13:20:31.693 algo-1:27 INFO hook.py:591] name:layer4.2.bn3.weight count_params:2048
# [2022-05-07 13:20:31.693 algo-1:27 INFO hook.py:591] name:layer4.2.bn3.bias count_params:2048
# [2022-05-07 13:20:31.694 algo-1:27 INFO hook.py:591] name:fc.weight count_params:2048000
# [2022-05-07 13:20:31.694 algo-1:27 INFO hook.py:591] name:fc.bias count_params:1000
# [2022-05-07 13:20:31.694 algo-1:27 INFO hook.py:593] Total Trainable Params: 25557032
# [2022-05-07 13:20:31.695 algo-1:27 INFO hook.py:425] Monitoring the collections: gradients, losses, relu_input
# [2022-05-07 13:20:31.697 algo-1:27 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/27-algo-1/prestepzero-*-start-1651929604417615.8_train-0-stepstart-1651929631697044.8/python_stats.
# [2022-05-07 13:20:31.713 algo-1:27 INFO hook.py:488] Hook is writing from the hook with pid: 27
# [2022-05-07 13:20:49.985 algo-1:27 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/27-algo-1/train-0-stepstart-1651929631709751.8_train-0-forwardpassend-1651929649984893.0/python_stats.
# [2022-05-07 13:20:56.517 algo-1:27 INFO python_profiler.py:182] Dumping cProfile stats to /opt/ml/output/profiler/framework/pytorch/cprofile/27-algo-1/train-0-forwardpassend-1651929649988836.8_train-1-stepstart-1651929656515884.8/python_stats.
#
# 2022-05-07 13:22:29 Uploading - Uploading generated training model
# 2022-05-07 13:22:29 MaxWaitTimeExceeded - Training job wait time exceeded MaxWaitTimeInSeconds provided
# Job ended with status 'Stopped' rather than 'Completed'. This could mean the job timed out or stopped early for some other reason: Consider checking whether it completed as you expect.
# Training seconds: 409
# Billable seconds: 123
# Managed Spot Training savings: 69.9%

# %%
session = boto3.session.Session()
region = session.region_name

training_job_name = estimator.latest_training_job.name
print(f"Training jobname: {training_job_name}")
print(f"Region: {region}")
# Out:
# Training jobname: smdebugger-debugger-and-profiler-cifar--2022-05-07-12-49-57-160
# Region: eu-west-1

# %%
trial = create_trial(estimator.latest_job_debugger_artifacts_path())

print(trial.tensor_names())
print(len(trial.tensor("CrossEntropyLoss_output_0").steps(mode=ModeKeys.TRAIN)))
print(len(trial.tensor("CrossEntropyLoss_output_0").steps(mode=ModeKeys.EVAL)))
# Out:
# [2022-05-07 13:25:07.307 ip-172-16-17-202:32741 INFO s3_trial.py:42] Loading trial debug-output at path s3://sagemaker-eu-west-1-663084464644/smdebugger-debugger-and-profiler-cifar--2022-05-07-12-49-57-160/debug-output
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/boto3/compat.py:88: PythonDeprecationWarning: Boto3 will no longer support Python 3.6 starting May 30, 2022. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.7 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)
# ---------------------------------------------------------------------------
# MissingCollectionFiles                    Traceback (most recent call last)
# <ipython-input-16-03d4760f9f97> in <module>
# ----> 1 trial = create_trial(estimator.latest_job_debugger_artifacts_path())
#       2
#       3 print(trial.tensor_names())
#       4 print(len(trial.tensor("CrossEntropyLoss_output_0").steps(mode=ModeKeys.TRAIN)))
#       5 print(len(trial.tensor("CrossEntropyLoss_output_0").steps(mode=ModeKeys.EVAL)))
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/smdebug/trials/utils.py in create_trial(path, name, profiler, output_dir, **kwargs)
#      21         return ProfilerTrial(name=name, trial_dir=path, output_dir=output_dir, **kwargs)
#      22     if s3:
# ---> 23         return S3Trial(name=name, bucket_name=bucket_name, prefix_name=prefix_name, **kwargs)
#      24     else:
#      25         return LocalTrial(name=name, dirname=path, **kwargs)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/smdebug/trials/s3_trial.py in __init__(self, name, bucket_name, prefix_name, range_steps, check, index_mode, cache)
#      45         self.path = "s3://" + os.path.join(self.bucket_name, self.prefix_name)
#      46         self.index_reader = S3IndexReader(self.path)
# ---> 47         self._load_collections()
#      48         self.refresh_data()
#      49
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/smdebug/trials/trial.py in _load_collections(self)
#     166
#     167         _fetch()
# --> 168         _wait_for_collection_files(1)  # wait for the first collection file
#     169         self._read_collections(collection_files)
#     170         _wait_for_collection_files(self.num_workers)  # wait for all the collection files
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/smdebug/trials/trial.py in _wait_for_collection_files(number_of_collection_file_to_wait_for)
#     163                     """ _fetch should have returned all the collection files if the training job has ended """
#     164                     if len(collection_files) < number_of_collection_file_to_wait_for:
# --> 165                         raise MissingCollectionFiles
#     166
#     167         _fetch()
#
# MissingCollectionFiles: Training job has ended. All the collection files could not be loaded
